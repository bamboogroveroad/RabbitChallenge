# %% [markdown]
# # 準備

# %% [markdown]
# ## Googleドライブのマウント

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## sys.pathの設定

# %% [markdown]
# 以下では，Googleドライブのマイドライブ直下にDNN_codeフォルダを置くことを仮定しています．必要に応じて，パスを変更してください．

# %%
import sys
sys.path.append('/content/drive/My Drive/DNN_code')
sys.path.append('/content/drive/My Drive/DNN_code/lesson_2')

# %% [markdown]
# # optimizer

# %% [markdown]
# ## SGD
# バッチ正規化を有効にした。

# %%
import sys, os
sys.path.append(os.pardir)  # 親ディレクトリのファイルをインポートするための設定
import numpy as np
from collections import OrderedDict
from common import layers
from data.mnist import load_mnist
import matplotlib.pyplot as plt
from multi_layer_net import MultiLayerNet


# データの読み込み
(x_train, d_train), (x_test, d_test) = load_mnist(normalize=True, one_hot_label=True)

print("データ読み込み完了")

# batch_normalizationの設定 ================================
# use_batchnorm = True
use_batchnorm = True
# ====================================================


network = MultiLayerNet(input_size=784, hidden_size_list=[40, 20], output_size=10, activation='sigmoid', weight_init_std=0.01,
                       use_batchnorm=use_batchnorm)

iters_num = 1000
train_size = x_train.shape[0]
batch_size = 100
learning_rate = 0.01

train_loss_list = []
accuracies_train = []
accuracies_test = []

plot_interval=10

for i in range(iters_num):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    d_batch = d_train[batch_mask]

    # 勾配
    grad = network.gradient(x_batch, d_batch)
    
    for key in ('W1', 'W2', 'W3', 'b1', 'b2', 'b3'):
        network.params[key] -= learning_rate * grad[key]
        
        loss = network.loss(x_batch, d_batch)
        train_loss_list.append(loss)
    
    
    if (i + 1) % plot_interval == 0:
        accr_test = network.accuracy(x_test, d_test)
        accuracies_test.append(accr_test)        
        accr_train = network.accuracy(x_batch, d_batch)
        accuracies_train.append(accr_train)
        
        print('Generation: ' + str(i+1) + '. 正答率(トレーニング) = ' + str(accr_train))
        print('                : ' + str(i+1) + '. 正答率(テスト) = ' + str(accr_test))

        
lists = range(0, iters_num, plot_interval)
plt.plot(lists, accuracies_train, label="training set")
plt.plot(lists, accuracies_test,  label="test set")
plt.legend(loc="lower right")
plt.title("accuracy")
plt.xlabel("count")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
# グラフの表示
plt.show()
# Out:
# データ読み込み完了
# Generation: 10. 正答率(トレーニング) = 0.23
#                 : 10. 正答率(テスト) = 0.1606
# Generation: 20. 正答率(トレーニング) = 0.2
#                 : 20. 正答率(テスト) = 0.1872
# Generation: 30. 正答率(トレーニング) = 0.28
#                 : 30. 正答率(テスト) = 0.2788
# Generation: 40. 正答率(トレーニング) = 0.43
#                 : 40. 正答率(テスト) = 0.386
# Generation: 50. 正答率(トレーニング) = 0.41
#                 : 50. 正答率(テスト) = 0.3978
# Generation: 60. 正答率(トレーニング) = 0.53
#                 : 60. 正答率(テスト) = 0.4352
# Generation: 70. 正答率(トレーニング) = 0.34
#                 : 70. 正答率(テスト) = 0.4133
# Generation: 80. 正答率(トレーニング) = 0.38
#                 : 80. 正答率(テスト) = 0.3936
# Generation: 90. 正答率(トレーニング) = 0.41
#                 : 90. 正答率(テスト) = 0.3662
# Generation: 100. 正答率(トレーニング) = 0.31
#                 : 100. 正答率(テスト) = 0.3849
# Generation: 110. 正答率(トレーニング) = 0.46
#                 : 110. 正答率(テスト) = 0.3906
# Generation: 120. 正答率(トレーニング) = 0.41
#                 : 120. 正答率(テスト) = 0.403
# Generation: 130. 正答率(トレーニング) = 0.34
#                 : 130. 正答率(テスト) = 0.3823
# Generation: 140. 正答率(トレーニング) = 0.37
#                 : 140. 正答率(テスト) = 0.4125
# Generation: 150. 正答率(トレーニング) = 0.39
#                 : 150. 正答率(テスト) = 0.3532
# Generation: 160. 正答率(トレーニング) = 0.35
#                 : 160. 正答率(テスト) = 0.3742
# Generation: 170. 正答率(トレーニング) = 0.33
#                 : 170. 正答率(テスト) = 0.4429
# Generation: 180. 正答率(トレーニング) = 0.48
#                 : 180. 正答率(テスト) = 0.4437
# Generation: 190. 正答率(トレーニング) = 0.33
#                 : 190. 正答率(テスト) = 0.3858
# Generation: 200. 正答率(トレーニング) = 0.49
#                 : 200. 正答率(テスト) = 0.4238
# Generation: 210. 正答率(トレーニング) = 0.41
#                 : 210. 正答率(テスト) = 0.4277
# Generation: 220. 正答率(トレーニング) = 0.43
#                 : 220. 正答率(テスト) = 0.4243
# Generation: 230. 正答率(トレーニング) = 0.39
#                 : 230. 正答率(テスト) = 0.4385
# Generation: 240. 正答率(トレーニング) = 0.42
#                 : 240. 正答率(テスト) = 0.4297
# Generation: 250. 正答率(トレーニング) = 0.33
#                 : 250. 正答率(テスト) = 0.4044
# Generation: 260. 正答率(トレーニング) = 0.37
#                 : 260. 正答率(テスト) = 0.4112
# Generation: 270. 正答率(トレーニング) = 0.49
#                 : 270. 正答率(テスト) = 0.4317
# Generation: 280. 正答率(トレーニング) = 0.38
#                 : 280. 正答率(テスト) = 0.4341
# Generation: 290. 正答率(トレーニング) = 0.46
#                 : 290. 正答率(テスト) = 0.4154
# Generation: 300. 正答率(トレーニング) = 0.43
#                 : 300. 正答率(テスト) = 0.4139
# Generation: 310. 正答率(トレーニング) = 0.38
#                 : 310. 正答率(テスト) = 0.4157
# Generation: 320. 正答率(トレーニング) = 0.41
#                 : 320. 正答率(テスト) = 0.4402
# Generation: 330. 正答率(トレーニング) = 0.43
#                 : 330. 正答率(テスト) = 0.4142
# Generation: 340. 正答率(トレーニング) = 0.47
#                 : 340. 正答率(テスト) = 0.437
# Generation: 350. 正答率(トレーニング) = 0.46
#                 : 350. 正答率(テスト) = 0.4316
# Generation: 360. 正答率(トレーニング) = 0.28
#                 : 360. 正答率(テスト) = 0.4142
# Generation: 370. 正答率(トレーニング) = 0.44
#                 : 370. 正答率(テスト) = 0.4157
# Generation: 380. 正答率(トレーニング) = 0.47
#                 : 380. 正答率(テスト) = 0.4644
# Generation: 390. 正答率(トレーニング) = 0.44
#                 : 390. 正答率(テスト) = 0.4444
# Generation: 400. 正答率(トレーニング) = 0.33
#                 : 400. 正答率(テスト) = 0.4518
# Generation: 410. 正答率(トレーニング) = 0.39
#                 : 410. 正答率(テスト) = 0.4529
# Generation: 420. 正答率(トレーニング) = 0.53
#                 : 420. 正答率(テスト) = 0.4751
# Generation: 430. 正答率(トレーニング) = 0.47
#                 : 430. 正答率(テスト) = 0.4805
# Generation: 440. 正答率(トレーニング) = 0.42
#                 : 440. 正答率(テスト) = 0.467
# Generation: 450. 正答率(トレーニング) = 0.49
#                 : 450. 正答率(テスト) = 0.4775
# Generation: 460. 正答率(トレーニング) = 0.54
#                 : 460. 正答率(テスト) = 0.4797
# Generation: 470. 正答率(トレーニング) = 0.46
#                 : 470. 正答率(テスト) = 0.5003
# Generation: 480. 正答率(トレーニング) = 0.58
#                 : 480. 正答率(テスト) = 0.5045
# Generation: 490. 正答率(トレーニング) = 0.53
#                 : 490. 正答率(テスト) = 0.5154
# Generation: 500. 正答率(トレーニング) = 0.52
#                 : 500. 正答率(テスト) = 0.5182
# Generation: 510. 正答率(トレーニング) = 0.54
#                 : 510. 正答率(テスト) = 0.5147
# Generation: 520. 正答率(トレーニング) = 0.52
#                 : 520. 正答率(テスト) = 0.5096
# Generation: 530. 正答率(トレーニング) = 0.55
#                 : 530. 正答率(テスト) = 0.5038
# Generation: 540. 正答率(トレーニング) = 0.46
#                 : 540. 正答率(テスト) = 0.5227
# Generation: 550. 正答率(トレーニング) = 0.55
#                 : 550. 正答率(テスト) = 0.5436
# Generation: 560. 正答率(トレーニング) = 0.55
#                 : 560. 正答率(テスト) = 0.5586
# Generation: 570. 正答率(トレーニング) = 0.6
#                 : 570. 正答率(テスト) = 0.5491
# Generation: 580. 正答率(トレーニング) = 0.53
#                 : 580. 正答率(テスト) = 0.5431
# Generation: 590. 正答率(トレーニング) = 0.63
#                 : 590. 正答率(テスト) = 0.5578
# Generation: 600. 正答率(トレーニング) = 0.56
#                 : 600. 正答率(テスト) = 0.5829
# Generation: 610. 正答率(トレーニング) = 0.57
#                 : 610. 正答率(テスト) = 0.6024
# Generation: 620. 正答率(トレーニング) = 0.62
#                 : 620. 正答率(テスト) = 0.6107
# Generation: 630. 正答率(トレーニング) = 0.6
#                 : 630. 正答率(テスト) = 0.6168
# Generation: 640. 正答率(トレーニング) = 0.65
#                 : 640. 正答率(テスト) = 0.5977
# Generation: 650. 正答率(トレーニング) = 0.62
#                 : 650. 正答率(テスト) = 0.6142
# Generation: 660. 正答率(トレーニング) = 0.57
#                 : 660. 正答率(テスト) = 0.6054
# Generation: 670. 正答率(トレーニング) = 0.54
#                 : 670. 正答率(テスト) = 0.6017
# Generation: 680. 正答率(トレーニング) = 0.69
#                 : 680. 正答率(テスト) = 0.6147
# Generation: 690. 正答率(トレーニング) = 0.62
#                 : 690. 正答率(テスト) = 0.6147
# Generation: 700. 正答率(トレーニング) = 0.58
#                 : 700. 正答率(テスト) = 0.6262
# Generation: 710. 正答率(トレーニング) = 0.59
#                 : 710. 正答率(テスト) = 0.6276
# Generation: 720. 正答率(トレーニング) = 0.65
#                 : 720. 正答率(テスト) = 0.6339
# Generation: 730. 正答率(トレーニング) = 0.65
#                 : 730. 正答率(テスト) = 0.6477
# Generation: 740. 正答率(トレーニング) = 0.71
#                 : 740. 正答率(テスト) = 0.641
# Generation: 750. 正答率(トレーニング) = 0.61
#                 : 750. 正答率(テスト) = 0.6382
# Generation: 760. 正答率(トレーニング) = 0.59
#                 : 760. 正答率(テスト) = 0.6252
# Generation: 770. 正答率(トレーニング) = 0.68
#                 : 770. 正答率(テスト) = 0.6333
# Generation: 780. 正答率(トレーニング) = 0.64
#                 : 780. 正答率(テスト) = 0.6282
# Generation: 790. 正答率(トレーニング) = 0.55
#                 : 790. 正答率(テスト) = 0.6297
# Generation: 800. 正答率(トレーニング) = 0.6
#                 : 800. 正答率(テスト) = 0.6468
# Generation: 810. 正答率(トレーニング) = 0.6
#                 : 810. 正答率(テスト) = 0.6481
# Generation: 820. 正答率(トレーニング) = 0.6
#                 : 820. 正答率(テスト) = 0.6508
# Generation: 830. 正答率(トレーニング) = 0.62
#                 : 830. 正答率(テスト) = 0.645
# Generation: 840. 正答率(トレーニング) = 0.67
#                 : 840. 正答率(テスト) = 0.6582
# Generation: 850. 正答率(トレーニング) = 0.57
#                 : 850. 正答率(テスト) = 0.6513
# Generation: 860. 正答率(トレーニング) = 0.69
#                 : 860. 正答率(テスト) = 0.6508
# Generation: 870. 正答率(トレーニング) = 0.66
#                 : 870. 正答率(テスト) = 0.6446
# Generation: 880. 正答率(トレーニング) = 0.73
#                 : 880. 正答率(テスト) = 0.6462
# Generation: 890. 正答率(トレーニング) = 0.64
#                 : 890. 正答率(テスト) = 0.6701
# Generation: 900. 正答率(トレーニング) = 0.71
#                 : 900. 正答率(テスト) = 0.661
# Generation: 910. 正答率(トレーニング) = 0.66
#                 : 910. 正答率(テスト) = 0.6466
# Generation: 920. 正答率(トレーニング) = 0.71
#                 : 920. 正答率(テスト) = 0.6525
# Generation: 930. 正答率(トレーニング) = 0.7
#                 : 930. 正答率(テスト) = 0.6595
# Generation: 940. 正答率(トレーニング) = 0.61
#                 : 940. 正答率(テスト) = 0.6597
# Generation: 950. 正答率(トレーニング) = 0.69
#                 : 950. 正答率(テスト) = 0.6559
# Generation: 960. 正答率(トレーニング) = 0.62
#                 : 960. 正答率(テスト) = 0.6525
# Generation: 970. 正答率(トレーニング) = 0.6
#                 : 970. 正答率(テスト) = 0.6531
# Generation: 980. 正答率(トレーニング) = 0.7
#                 : 980. 正答率(テスト) = 0.665
# Generation: 990. 正答率(トレーニング) = 0.71
#                 : 990. 正答率(テスト) = 0.6501
# Generation: 1000. 正答率(トレーニング) = 0.72
#                 : 1000. 正答率(テスト) = 0.64

# %% [markdown]
# →ある低度学習が進んだが、まだ正答率が低い。

# %% [markdown]
# ## Momentum
# バッチ正規化を有効にした。

# %%
# データの読み込み
(x_train, d_train), (x_test, d_test) = load_mnist(normalize=True, one_hot_label=True)

print("データ読み込み完了")

# batch_normalizationの設定 ================================
use_batchnorm = True
# use_batchnorm = False
# ====================================================

network = MultiLayerNet(input_size=784, hidden_size_list=[40, 20], output_size=10, activation='sigmoid', weight_init_std=0.01,
                       use_batchnorm=use_batchnorm)

iters_num = 1000
train_size = x_train.shape[0]
batch_size = 100
learning_rate = 0.01
# 慣性
momentum = 0.9

train_loss_list = []
accuracies_train = []
accuracies_test = []

plot_interval=10

for i in range(iters_num):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    d_batch = d_train[batch_mask]

    # 勾配
    grad = network.gradient(x_batch, d_batch)
    if i == 0:
        v = {}
    for key in ('W1', 'W2', 'W3', 'b1', 'b2', 'b3'):
        if i == 0:
            v[key] = np.zeros_like(network.params[key])
        v[key] = momentum * v[key] - learning_rate * grad[key]
        network.params[key] += v[key]

        loss = network.loss(x_batch, d_batch)
        train_loss_list.append(loss)
        
    if (i + 1) % plot_interval == 0:
        accr_test = network.accuracy(x_test, d_test)
        accuracies_test.append(accr_test)        
        accr_train = network.accuracy(x_batch, d_batch)
        accuracies_train.append(accr_train)

        print('Generation: ' + str(i+1) + '. 正答率(トレーニング) = ' + str(accr_train))
        print('                : ' + str(i+1) + '. 正答率(テスト) = ' + str(accr_test))
        
        
lists = range(0, iters_num, plot_interval)
plt.plot(lists, accuracies_train, label="training set")
plt.plot(lists, accuracies_test,  label="test set")
plt.legend(loc="lower right")
plt.title("accuracy")
plt.xlabel("count")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
# グラフの表示
plt.show()
# Out:
# データ読み込み完了
# Generation: 10. 正答率(トレーニング) = 0.17
#                 : 10. 正答率(テスト) = 0.1807
# Generation: 20. 正答率(トレーニング) = 0.32
#                 : 20. 正答率(テスト) = 0.3051
# Generation: 30. 正答率(トレーニング) = 0.44
#                 : 30. 正答率(テスト) = 0.4225
# Generation: 40. 正答率(トレーニング) = 0.46
#                 : 40. 正答率(テスト) = 0.3467
# Generation: 50. 正答率(トレーニング) = 0.41
#                 : 50. 正答率(テスト) = 0.404
# Generation: 60. 正答率(トレーニング) = 0.45
#                 : 60. 正答率(テスト) = 0.453
# Generation: 70. 正答率(トレーニング) = 0.45
#                 : 70. 正答率(テスト) = 0.5028
# Generation: 80. 正答率(トレーニング) = 0.65
#                 : 80. 正答率(テスト) = 0.5602
# Generation: 90. 正答率(トレーニング) = 0.6
#                 : 90. 正答率(テスト) = 0.6231
# Generation: 100. 正答率(トレーニング) = 0.59
#                 : 100. 正答率(テスト) = 0.6419
# Generation: 110. 正答率(トレーニング) = 0.57
#                 : 110. 正答率(テスト) = 0.6239
# Generation: 120. 正答率(トレーニング) = 0.62
#                 : 120. 正答率(テスト) = 0.6189
# Generation: 130. 正答率(トレーニング) = 0.64
#                 : 130. 正答率(テスト) = 0.616
# Generation: 140. 正答率(トレーニング) = 0.57
#                 : 140. 正答率(テスト) = 0.6575
# Generation: 150. 正答率(トレーニング) = 0.66
#                 : 150. 正答率(テスト) = 0.6526
# Generation: 160. 正答率(トレーニング) = 0.66
#                 : 160. 正答率(テスト) = 0.6696
# Generation: 170. 正答率(トレーニング) = 0.61
#                 : 170. 正答率(テスト) = 0.6587
# Generation: 180. 正答率(トレーニング) = 0.69
#                 : 180. 正答率(テスト) = 0.7199
# Generation: 190. 正答率(トレーニング) = 0.73
#                 : 190. 正答率(テスト) = 0.7318
# Generation: 200. 正答率(トレーニング) = 0.77
#                 : 200. 正答率(テスト) = 0.7584
# Generation: 210. 正答率(トレーニング) = 0.76
#                 : 210. 正答率(テスト) = 0.7702
# Generation: 220. 正答率(トレーニング) = 0.73
#                 : 220. 正答率(テスト) = 0.7451
# Generation: 230. 正答率(トレーニング) = 0.8
#                 : 230. 正答率(テスト) = 0.7583
# Generation: 240. 正答率(トレーニング) = 0.76
#                 : 240. 正答率(テスト) = 0.7797
# Generation: 250. 正答率(トレーニング) = 0.88
#                 : 250. 正答率(テスト) = 0.7833
# Generation: 260. 正答率(トレーニング) = 0.82
#                 : 260. 正答率(テスト) = 0.7971
# Generation: 270. 正答率(トレーニング) = 0.75
#                 : 270. 正答率(テスト) = 0.7755
# Generation: 280. 正答率(トレーニング) = 0.8
#                 : 280. 正答率(テスト) = 0.7681
# Generation: 290. 正答率(トレーニング) = 0.77
#                 : 290. 正答率(テスト) = 0.7952
# Generation: 300. 正答率(トレーニング) = 0.77
#                 : 300. 正答率(テスト) = 0.8067
# Generation: 310. 正答率(トレーニング) = 0.83
#                 : 310. 正答率(テスト) = 0.7994
# Generation: 320. 正答率(トレーニング) = 0.81
#                 : 320. 正答率(テスト) = 0.8081
# Generation: 330. 正答率(トレーニング) = 0.84
#                 : 330. 正答率(テスト) = 0.8036
# Generation: 340. 正答率(トレーニング) = 0.75
#                 : 340. 正答率(テスト) = 0.8159
# Generation: 350. 正答率(トレーニング) = 0.83
#                 : 350. 正答率(テスト) = 0.8295
# Generation: 360. 正答率(トレーニング) = 0.82
#                 : 360. 正答率(テスト) = 0.8322
# Generation: 370. 正答率(トレーニング) = 0.87
#                 : 370. 正答率(テスト) = 0.8264
# Generation: 380. 正答率(トレーニング) = 0.82
#                 : 380. 正答率(テスト) = 0.8261
# Generation: 390. 正答率(トレーニング) = 0.84
#                 : 390. 正答率(テスト) = 0.8505
# Generation: 400. 正答率(トレーニング) = 0.84
#                 : 400. 正答率(テスト) = 0.8318
# Generation: 410. 正答率(トレーニング) = 0.84
#                 : 410. 正答率(テスト) = 0.8515
# Generation: 420. 正答率(トレーニング) = 0.81
#                 : 420. 正答率(テスト) = 0.8427
# Generation: 430. 正答率(トレーニング) = 0.85
#                 : 430. 正答率(テスト) = 0.8238
# Generation: 440. 正答率(トレーニング) = 0.84
#                 : 440. 正答率(テスト) = 0.8518
# Generation: 450. 正答率(トレーニング) = 0.84
#                 : 450. 正答率(テスト) = 0.8532
# Generation: 460. 正答率(トレーニング) = 0.87
#                 : 460. 正答率(テスト) = 0.8606
# Generation: 470. 正答率(トレーニング) = 0.89
#                 : 470. 正答率(テスト) = 0.8645
# Generation: 480. 正答率(トレーニング) = 0.85
#                 : 480. 正答率(テスト) = 0.8793
# Generation: 490. 正答率(トレーニング) = 0.9
#                 : 490. 正答率(テスト) = 0.8726
# Generation: 500. 正答率(トレーニング) = 0.84
#                 : 500. 正答率(テスト) = 0.8801
# Generation: 510. 正答率(トレーニング) = 0.9
#                 : 510. 正答率(テスト) = 0.8768
# Generation: 520. 正答率(トレーニング) = 0.82
#                 : 520. 正答率(テスト) = 0.8726
# Generation: 530. 正答率(トレーニング) = 0.88
#                 : 530. 正答率(テスト) = 0.8702
# Generation: 540. 正答率(トレーニング) = 0.92
#                 : 540. 正答率(テスト) = 0.8815
# Generation: 550. 正答率(トレーニング) = 0.88
#                 : 550. 正答率(テスト) = 0.8739
# Generation: 560. 正答率(トレーニング) = 0.93
#                 : 560. 正答率(テスト) = 0.8814
# Generation: 570. 正答率(トレーニング) = 0.82
#                 : 570. 正答率(テスト) = 0.8802
# Generation: 580. 正答率(トレーニング) = 0.88
#                 : 580. 正答率(テスト) = 0.88
# Generation: 590. 正答率(トレーニング) = 0.88
#                 : 590. 正答率(テスト) = 0.8814
# Generation: 600. 正答率(トレーニング) = 0.96
#                 : 600. 正答率(テスト) = 0.8789
# Generation: 610. 正答率(トレーニング) = 0.88
#                 : 610. 正答率(テスト) = 0.8857
# Generation: 620. 正答率(トレーニング) = 0.94
#                 : 620. 正答率(テスト) = 0.8954
# Generation: 630. 正答率(トレーニング) = 0.92
#                 : 630. 正答率(テスト) = 0.8891
# Generation: 640. 正答率(トレーニング) = 0.89
#                 : 640. 正答率(テスト) = 0.8824
# Generation: 650. 正答率(トレーニング) = 0.86
#                 : 650. 正答率(テスト) = 0.8922
# Generation: 660. 正答率(トレーニング) = 0.87
#                 : 660. 正答率(テスト) = 0.8913
# Generation: 670. 正答率(トレーニング) = 0.86
#                 : 670. 正答率(テスト) = 0.8921
# Generation: 680. 正答率(トレーニング) = 0.87
#                 : 680. 正答率(テスト) = 0.8946
# Generation: 690. 正答率(トレーニング) = 0.9
#                 : 690. 正答率(テスト) = 0.8887
# Generation: 700. 正答率(トレーニング) = 0.83
#                 : 700. 正答率(テスト) = 0.8846
# Generation: 710. 正答率(トレーニング) = 0.92
#                 : 710. 正答率(テスト) = 0.8809
# Generation: 720. 正答率(トレーニング) = 0.93
#                 : 720. 正答率(テスト) = 0.8945
# Generation: 730. 正答率(トレーニング) = 0.9
#                 : 730. 正答率(テスト) = 0.899
# Generation: 740. 正答率(トレーニング) = 0.91
#                 : 740. 正答率(テスト) = 0.9008
# Generation: 750. 正答率(トレーニング) = 0.95
#                 : 750. 正答率(テスト) = 0.8969
# Generation: 760. 正答率(トレーニング) = 0.89
#                 : 760. 正答率(テスト) = 0.8961
# Generation: 770. 正答率(トレーニング) = 0.9
#                 : 770. 正答率(テスト) = 0.8989
# Generation: 780. 正答率(トレーニング) = 0.89
#                 : 780. 正答率(テスト) = 0.894
# Generation: 790. 正答率(トレーニング) = 0.84
#                 : 790. 正答率(テスト) = 0.8956
# Generation: 800. 正答率(トレーニング) = 0.87
#                 : 800. 正答率(テスト) = 0.8971
# Generation: 810. 正答率(トレーニング) = 0.87
#                 : 810. 正答率(テスト) = 0.8974
# Generation: 820. 正答率(トレーニング) = 0.91
#                 : 820. 正答率(テスト) = 0.8913
# Generation: 830. 正答率(トレーニング) = 0.94
#                 : 830. 正答率(テスト) = 0.9051
# Generation: 840. 正答率(トレーニング) = 0.87
#                 : 840. 正答率(テスト) = 0.9064
# Generation: 850. 正答率(トレーニング) = 0.9
#                 : 850. 正答率(テスト) = 0.9062
# Generation: 860. 正答率(トレーニング) = 0.91
#                 : 860. 正答率(テスト) = 0.8972
# Generation: 870. 正答率(トレーニング) = 0.91
#                 : 870. 正答率(テスト) = 0.905
# Generation: 880. 正答率(トレーニング) = 0.85
#                 : 880. 正答率(テスト) = 0.9041
# Generation: 890. 正答率(トレーニング) = 0.88
#                 : 890. 正答率(テスト) = 0.897
# Generation: 900. 正答率(トレーニング) = 0.91
#                 : 900. 正答率(テスト) = 0.9006
# Generation: 910. 正答率(トレーニング) = 0.89
#                 : 910. 正答率(テスト) = 0.9092
# Generation: 920. 正答率(トレーニング) = 0.91
#                 : 920. 正答率(テスト) = 0.9043
# Generation: 930. 正答率(トレーニング) = 0.91
#                 : 930. 正答率(テスト) = 0.8986
# Generation: 940. 正答率(トレーニング) = 0.91
#                 : 940. 正答率(テスト) = 0.9062
# Generation: 950. 正答率(トレーニング) = 0.9
#                 : 950. 正答率(テスト) = 0.9013
# Generation: 960. 正答率(トレーニング) = 0.9
#                 : 960. 正答率(テスト) = 0.9108
# Generation: 970. 正答率(トレーニング) = 0.87
#                 : 970. 正答率(テスト) = 0.9074
# Generation: 980. 正答率(トレーニング) = 0.89
#                 : 980. 正答率(テスト) = 0.9099
# Generation: 990. 正答率(トレーニング) = 0.93
#                 : 990. 正答率(テスト) = 0.9042
# Generation: 1000. 正答率(トレーニング) = 0.89
#                 : 1000. 正答率(テスト) = 0.9083

# %% [markdown]
# →正答率が高く学習がうまくいった。

# %% [markdown]
# ## MomentumをもとにAdaGradを作ってみよう
# θ = 1e-4 とする
#
# バッチ正規化を有効にした。

# %%
# AdaGradを作ってみよう
# データの読み込み
(x_train, d_train), (x_test, d_test) = load_mnist(normalize=True, one_hot_label=True)

print("データ読み込み完了")

# batch_normalizationの設定 ================================
use_batchnorm = True
# use_batchnorm = False
# ====================================================

network = MultiLayerNet(input_size=784, hidden_size_list=[40, 20], output_size=10, activation='sigmoid', weight_init_std=0.01,
                       use_batchnorm=use_batchnorm)

iters_num = 1000
# iters_num = 500 # 処理を短縮

train_size = x_train.shape[0]
batch_size = 100
learning_rate = 0.01

# AdaGradでは不必要
# =============================

momentum = 0.9 

# =============================

train_loss_list = []
accuracies_train = []
accuracies_test = []

plot_interval=10

for i in range(iters_num):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    d_batch = d_train[batch_mask]

    # 勾配
    grad = network.gradient(x_batch, d_batch)
    if i == 0:
        h = {}
    for key in ('W1', 'W2', 'W3', 'b1', 'b2', 'b3'):
            
        # 変更しよう  
        # ===========================================
        if i == 0:
            h[key] = np.zeros_like(network.params[key])        
        h[key] = momentum * h[key] - learning_rate * grad[key]
        network.params[key] += h[key]

        # ===========================================
        
        loss = network.loss(x_batch, d_batch)
        train_loss_list.append(loss)
        
    if (i + 1) % plot_interval == 0:
        accr_test = network.accuracy(x_test, d_test)
        accuracies_test.append(accr_test)        
        accr_train = network.accuracy(x_batch, d_batch)
        accuracies_train.append(accr_train)

        print('Generation: ' + str(i+1) + '. 正答率(トレーニング) = ' + str(accr_train))
        print('                : ' + str(i+1) + '. 正答率(テスト) = ' + str(accr_test))
        
        
lists = range(0, iters_num, plot_interval)
plt.plot(lists, accuracies_train, label="training set")
plt.plot(lists, accuracies_test,  label="test set")
plt.legend(loc="lower right")
plt.title("accuracy")
plt.xlabel("count")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
# グラフの表示
plt.show()
# Out:
# データ読み込み完了
# Generation: 10. 正答率(トレーニング) = 0.31
#                 : 10. 正答率(テスト) = 0.2131
# Generation: 20. 正答率(トレーニング) = 0.37
#                 : 20. 正答率(テスト) = 0.2632
# Generation: 30. 正答率(トレーニング) = 0.34
#                 : 30. 正答率(テスト) = 0.2889
# Generation: 40. 正答率(トレーニング) = 0.33
#                 : 40. 正答率(テスト) = 0.3336
# Generation: 50. 正答率(トレーニング) = 0.37
#                 : 50. 正答率(テスト) = 0.4179
# Generation: 60. 正答率(トレーニング) = 0.52
#                 : 60. 正答率(テスト) = 0.4857
# Generation: 70. 正答率(トレーニング) = 0.5
#                 : 70. 正答率(テスト) = 0.5629
# Generation: 80. 正答率(トレーニング) = 0.53
#                 : 80. 正答率(テスト) = 0.5808
# Generation: 90. 正答率(トレーニング) = 0.6
#                 : 90. 正答率(テスト) = 0.6289
# Generation: 100. 正答率(トレーニング) = 0.65
#                 : 100. 正答率(テスト) = 0.6092
# Generation: 110. 正答率(トレーニング) = 0.56
#                 : 110. 正答率(テスト) = 0.6006
# Generation: 120. 正答率(トレーニング) = 0.6
#                 : 120. 正答率(テスト) = 0.6163
# Generation: 130. 正答率(トレーニング) = 0.69
#                 : 130. 正答率(テスト) = 0.638
# Generation: 140. 正答率(トレーニング) = 0.63
#                 : 140. 正答率(テスト) = 0.6263
# Generation: 150. 正答率(トレーニング) = 0.69
#                 : 150. 正答率(テスト) = 0.6251
# Generation: 160. 正答率(トレーニング) = 0.67
#                 : 160. 正答率(テスト) = 0.6527
# Generation: 170. 正答率(トレーニング) = 0.74
#                 : 170. 正答率(テスト) = 0.6893
# Generation: 180. 正答率(トレーニング) = 0.7
#                 : 180. 正答率(テスト) = 0.6948
# Generation: 190. 正答率(トレーニング) = 0.65
#                 : 190. 正答率(テスト) = 0.7425
# Generation: 200. 正答率(トレーニング) = 0.78
#                 : 200. 正答率(テスト) = 0.7418
# Generation: 210. 正答率(トレーニング) = 0.79
#                 : 210. 正答率(テスト) = 0.7279
# Generation: 220. 正答率(トレーニング) = 0.63
#                 : 220. 正答率(テスト) = 0.7155
# Generation: 230. 正答率(トレーニング) = 0.73
#                 : 230. 正答率(テスト) = 0.7709
# Generation: 240. 正答率(トレーニング) = 0.75
#                 : 240. 正答率(テスト) = 0.7333
# Generation: 250. 正答率(トレーニング) = 0.79
#                 : 250. 正答率(テスト) = 0.7346
# Generation: 260. 正答率(トレーニング) = 0.78
#                 : 260. 正答率(テスト) = 0.7416
# Generation: 270. 正答率(トレーニング) = 0.81
#                 : 270. 正答率(テスト) = 0.7463
# Generation: 280. 正答率(トレーニング) = 0.78
#                 : 280. 正答率(テスト) = 0.7495
# Generation: 290. 正答率(トレーニング) = 0.79
#                 : 290. 正答率(テスト) = 0.785
# Generation: 300. 正答率(トレーニング) = 0.81
#                 : 300. 正答率(テスト) = 0.7808
# Generation: 310. 正答率(トレーニング) = 0.71
#                 : 310. 正答率(テスト) = 0.7815
# Generation: 320. 正答率(トレーニング) = 0.76
#                 : 320. 正答率(テスト) = 0.784
# Generation: 330. 正答率(トレーニング) = 0.82
#                 : 330. 正答率(テスト) = 0.7855
# Generation: 340. 正答率(トレーニング) = 0.81
#                 : 340. 正答率(テスト) = 0.7856
# Generation: 350. 正答率(トレーニング) = 0.74
#                 : 350. 正答率(テスト) = 0.8256
# Generation: 360. 正答率(トレーニング) = 0.83
#                 : 360. 正答率(テスト) = 0.8319
# Generation: 370. 正答率(トレーニング) = 0.87
#                 : 370. 正答率(テスト) = 0.8469
# Generation: 380. 正答率(トレーニング) = 0.8
#                 : 380. 正答率(テスト) = 0.8348
# Generation: 390. 正答率(トレーニング) = 0.84
#                 : 390. 正答率(テスト) = 0.8408
# Generation: 400. 正答率(トレーニング) = 0.82
#                 : 400. 正答率(テスト) = 0.8414
# Generation: 410. 正答率(トレーニング) = 0.82
#                 : 410. 正答率(テスト) = 0.8306
# Generation: 420. 正答率(トレーニング) = 0.85
#                 : 420. 正答率(テスト) = 0.827
# Generation: 430. 正答率(トレーニング) = 0.84
#                 : 430. 正答率(テスト) = 0.8295
# Generation: 440. 正答率(トレーニング) = 0.88
#                 : 440. 正答率(テスト) = 0.8571
# Generation: 450. 正答率(トレーニング) = 0.88
#                 : 450. 正答率(テスト) = 0.8547
# Generation: 460. 正答率(トレーニング) = 0.86
#                 : 460. 正答率(テスト) = 0.8547
# Generation: 470. 正答率(トレーニング) = 0.87
#                 : 470. 正答率(テスト) = 0.8527
# Generation: 480. 正答率(トレーニング) = 0.88
#                 : 480. 正答率(テスト) = 0.8651
# Generation: 490. 正答率(トレーニング) = 0.81
#                 : 490. 正答率(テスト) = 0.8637
# Generation: 500. 正答率(トレーニング) = 0.89
#                 : 500. 正答率(テスト) = 0.8445
# Generation: 510. 正答率(トレーニング) = 0.87
#                 : 510. 正答率(テスト) = 0.8593
# Generation: 520. 正答率(トレーニング) = 0.86
#                 : 520. 正答率(テスト) = 0.8665
# Generation: 530. 正答率(トレーニング) = 0.85
#                 : 530. 正答率(テスト) = 0.859
# Generation: 540. 正答率(トレーニング) = 0.86
#                 : 540. 正答率(テスト) = 0.8606
# Generation: 550. 正答率(トレーニング) = 0.92
#                 : 550. 正答率(テスト) = 0.8674
# Generation: 560. 正答率(トレーニング) = 0.91
#                 : 560. 正答率(テスト) = 0.8696
# Generation: 570. 正答率(トレーニング) = 0.88
#                 : 570. 正答率(テスト) = 0.8624
# Generation: 580. 正答率(トレーニング) = 0.9
#                 : 580. 正答率(テスト) = 0.8794
# Generation: 590. 正答率(トレーニング) = 0.84
#                 : 590. 正答率(テスト) = 0.8757
# Generation: 600. 正答率(トレーニング) = 0.84
#                 : 600. 正答率(テスト) = 0.8755
# Generation: 610. 正答率(トレーニング) = 0.82
#                 : 610. 正答率(テスト) = 0.8716
# Generation: 620. 正答率(トレーニング) = 0.92
#                 : 620. 正答率(テスト) = 0.8807
# Generation: 630. 正答率(トレーニング) = 0.8
#                 : 630. 正答率(テスト) = 0.8799
# Generation: 640. 正答率(トレーニング) = 0.87
#                 : 640. 正答率(テスト) = 0.8835
# Generation: 650. 正答率(トレーニング) = 0.94
#                 : 650. 正答率(テスト) = 0.8829
# Generation: 660. 正答率(トレーニング) = 0.88
#                 : 660. 正答率(テスト) = 0.8781
# Generation: 670. 正答率(トレーニング) = 0.84
#                 : 670. 正答率(テスト) = 0.8851
# Generation: 680. 正答率(トレーニング) = 0.93
#                 : 680. 正答率(テスト) = 0.89
# Generation: 690. 正答率(トレーニング) = 0.85
#                 : 690. 正答率(テスト) = 0.8876
# Generation: 700. 正答率(トレーニング) = 0.93
#                 : 700. 正答率(テスト) = 0.8875
# Generation: 710. 正答率(トレーニング) = 0.91
#                 : 710. 正答率(テスト) = 0.8829
# Generation: 720. 正答率(トレーニング) = 0.9
#                 : 720. 正答率(テスト) = 0.8913
# Generation: 730. 正答率(トレーニング) = 0.9
#                 : 730. 正答率(テスト) = 0.8761
# Generation: 740. 正答率(トレーニング) = 0.89
#                 : 740. 正答率(テスト) = 0.8915
# Generation: 750. 正答率(トレーニング) = 0.85
#                 : 750. 正答率(テスト) = 0.8901
# Generation: 760. 正答率(トレーニング) = 0.91
#                 : 760. 正答率(テスト) = 0.8883
# Generation: 770. 正答率(トレーニング) = 0.9
#                 : 770. 正答率(テスト) = 0.8953
# Generation: 780. 正答率(トレーニング) = 0.89
#                 : 780. 正答率(テスト) = 0.8955
# Generation: 790. 正答率(トレーニング) = 0.85
#                 : 790. 正答率(テスト) = 0.8969
# Generation: 800. 正答率(トレーニング) = 0.86
#                 : 800. 正答率(テスト) = 0.8923
# Generation: 810. 正答率(トレーニング) = 0.88
#                 : 810. 正答率(テスト) = 0.8964
# Generation: 820. 正答率(トレーニング) = 0.95
#                 : 820. 正答率(テスト) = 0.8959
# Generation: 830. 正答率(トレーニング) = 0.9
#                 : 830. 正答率(テスト) = 0.8977
# Generation: 840. 正答率(トレーニング) = 0.88
#                 : 840. 正答率(テスト) = 0.8932
# Generation: 850. 正答率(トレーニング) = 0.87
#                 : 850. 正答率(テスト) = 0.9
# Generation: 860. 正答率(トレーニング) = 0.91
#                 : 860. 正答率(テスト) = 0.8977
# Generation: 870. 正答率(トレーニング) = 0.87
#                 : 870. 正答率(テスト) = 0.8907
# Generation: 880. 正答率(トレーニング) = 0.89
#                 : 880. 正答率(テスト) = 0.8968
# Generation: 890. 正答率(トレーニング) = 0.93
#                 : 890. 正答率(テスト) = 0.8931
# Generation: 900. 正答率(トレーニング) = 0.88
#                 : 900. 正答率(テスト) = 0.8988
# Generation: 910. 正答率(トレーニング) = 0.87
#                 : 910. 正答率(テスト) = 0.9025
# Generation: 920. 正答率(トレーニング) = 0.86
#                 : 920. 正答率(テスト) = 0.9022
# Generation: 930. 正答率(トレーニング) = 0.88
#                 : 930. 正答率(テスト) = 0.9022
# Generation: 940. 正答率(トレーニング) = 0.9
#                 : 940. 正答率(テスト) = 0.8963
# Generation: 950. 正答率(トレーニング) = 0.9
#                 : 950. 正答率(テスト) = 0.8964
# Generation: 960. 正答率(トレーニング) = 0.88
#                 : 960. 正答率(テスト) = 0.9013
# Generation: 970. 正答率(トレーニング) = 0.91
#                 : 970. 正答率(テスト) = 0.8994
# Generation: 980. 正答率(トレーニング) = 0.93
#                 : 980. 正答率(テスト) = 0.9043
# Generation: 990. 正答率(トレーニング) = 0.88
#                 : 990. 正答率(テスト) = 0.9012
# Generation: 1000. 正答率(トレーニング) = 0.89
#                 : 1000. 正答率(テスト) = 0.9092

# %% [markdown]
# ## RSMprop

# %%
# データの読み込み
(x_train, d_train), (x_test, d_test) = load_mnist(normalize=True, one_hot_label=True)

print("データ読み込み完了")

# batch_normalizationの設定 ================================
# use_batchnorm = True
use_batchnorm = False
# ====================================================

network = MultiLayerNet(input_size=784, hidden_size_list=[40, 20], output_size=10, activation='sigmoid', weight_init_std=0.01,
                       use_batchnorm=use_batchnorm)

iters_num = 1000
train_size = x_train.shape[0]
batch_size = 100
learning_rate = 0.01
decay_rate = 0.99

train_loss_list = []
accuracies_train = []
accuracies_test = []

plot_interval=10

for i in range(iters_num):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    d_batch = d_train[batch_mask]

    # 勾配
    grad = network.gradient(x_batch, d_batch)
    if i == 0:
        h = {}
    for key in ('W1', 'W2', 'W3', 'b1', 'b2', 'b3'):
        if i == 0:
            h[key] = np.zeros_like(network.params[key])
        h[key] *= decay_rate
        h[key] += (1 - decay_rate) * np.square(grad[key])
        network.params[key] -= learning_rate * grad[key] / (np.sqrt(h[key]) + 1e-7)

        loss = network.loss(x_batch, d_batch)
        train_loss_list.append(loss)                
        
    if (i + 1) % plot_interval == 0:
        accr_test = network.accuracy(x_test, d_test)
        accuracies_test.append(accr_test)        
        accr_train = network.accuracy(x_batch, d_batch)
        accuracies_train.append(accr_train)
        
        print('Generation: ' + str(i+1) + '. 正答率(トレーニング) = ' + str(accr_train))
        print('                : ' + str(i+1) + '. 正答率(テスト) = ' + str(accr_test))
        
        
lists = range(0, iters_num, plot_interval)
plt.plot(lists, accuracies_train, label="training set")
plt.plot(lists, accuracies_test,  label="test set")
plt.legend(loc="lower right")
plt.title("accuracy")
plt.xlabel("count")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
# グラフの表示
plt.show()
# Out:
# データ読み込み完了
# Generation: 10. 正答率(トレーニング) = 0.15
#                 : 10. 正答率(テスト) = 0.1135
# Generation: 20. 正答率(トレーニング) = 0.22
#                 : 20. 正答率(テスト) = 0.2045
# Generation: 30. 正答率(トレーニング) = 0.34
#                 : 30. 正答率(テスト) = 0.2053
# Generation: 40. 正答率(トレーニング) = 0.32
#                 : 40. 正答率(テスト) = 0.2578
# Generation: 50. 正答率(トレーニング) = 0.32
#                 : 50. 正答率(テスト) = 0.3106
# Generation: 60. 正答率(トレーニング) = 0.39
#                 : 60. 正答率(テスト) = 0.3394
# Generation: 70. 正答率(トレーニング) = 0.5
#                 : 70. 正答率(テスト) = 0.3451
# Generation: 80. 正答率(トレーニング) = 0.52
#                 : 80. 正答率(テスト) = 0.3923
# Generation: 90. 正答率(トレーニング) = 0.46
#                 : 90. 正答率(テスト) = 0.437
# Generation: 100. 正答率(トレーニング) = 0.5
#                 : 100. 正答率(テスト) = 0.4248
# Generation: 110. 正答率(トレーニング) = 0.59
#                 : 110. 正答率(テスト) = 0.5261
# Generation: 120. 正答率(トレーニング) = 0.65
#                 : 120. 正答率(テスト) = 0.5349
# Generation: 130. 正答率(トレーニング) = 0.7
#                 : 130. 正答率(テスト) = 0.5299
# Generation: 140. 正答率(トレーニング) = 0.65
#                 : 140. 正答率(テスト) = 0.612
# Generation: 150. 正答率(トレーニング) = 0.65
#                 : 150. 正答率(テスト) = 0.6164
# Generation: 160. 正答率(トレーニング) = 0.73
#                 : 160. 正答率(テスト) = 0.6464
# Generation: 170. 正答率(トレーニング) = 0.72
#                 : 170. 正答率(テスト) = 0.7042
# Generation: 180. 正答率(トレーニング) = 0.8
#                 : 180. 正答率(テスト) = 0.7062
# Generation: 190. 正答率(トレーニング) = 0.8
#                 : 190. 正答率(テスト) = 0.7817
# Generation: 200. 正答率(トレーニング) = 0.8
#                 : 200. 正答率(テスト) = 0.7771
# Generation: 210. 正答率(トレーニング) = 0.87
#                 : 210. 正答率(テスト) = 0.7961
# Generation: 220. 正答率(トレーニング) = 0.82
#                 : 220. 正答率(テスト) = 0.8019
# Generation: 230. 正答率(トレーニング) = 0.9
#                 : 230. 正答率(テスト) = 0.8268
# Generation: 240. 正答率(トレーニング) = 0.85
#                 : 240. 正答率(テスト) = 0.8328
# Generation: 250. 正答率(トレーニング) = 0.84
#                 : 250. 正答率(テスト) = 0.838
# Generation: 260. 正答率(トレーニング) = 0.9
#                 : 260. 正答率(テスト) = 0.8471
# Generation: 270. 正答率(トレーニング) = 0.91
#                 : 270. 正答率(テスト) = 0.8519
# Generation: 280. 正答率(トレーニング) = 0.85
#                 : 280. 正答率(テスト) = 0.8395
# Generation: 290. 正答率(トレーニング) = 0.92
#                 : 290. 正答率(テスト) = 0.8678
# Generation: 300. 正答率(トレーニング) = 0.92
#                 : 300. 正答率(テスト) = 0.8719
# Generation: 310. 正答率(トレーニング) = 0.9
#                 : 310. 正答率(テスト) = 0.8689
# Generation: 320. 正答率(トレーニング) = 0.92
#                 : 320. 正答率(テスト) = 0.8696
# Generation: 330. 正答率(トレーニング) = 0.89
#                 : 330. 正答率(テスト) = 0.8803
# Generation: 340. 正答率(トレーニング) = 0.92
#                 : 340. 正答率(テスト) = 0.8821
# Generation: 350. 正答率(トレーニング) = 0.98
#                 : 350. 正答率(テスト) = 0.8855
# Generation: 360. 正答率(トレーニング) = 0.93
#                 : 360. 正答率(テスト) = 0.8846
# Generation: 370. 正答率(トレーニング) = 0.92
#                 : 370. 正答率(テスト) = 0.8842
# Generation: 380. 正答率(トレーニング) = 0.9
#                 : 380. 正答率(テスト) = 0.8876
# Generation: 390. 正答率(トレーニング) = 0.97
#                 : 390. 正答率(テスト) = 0.8921
# Generation: 400. 正答率(トレーニング) = 0.93
#                 : 400. 正答率(テスト) = 0.8937
# Generation: 410. 正答率(トレーニング) = 0.94
#                 : 410. 正答率(テスト) = 0.8909
# Generation: 420. 正答率(トレーニング) = 0.93
#                 : 420. 正答率(テスト) = 0.8924
# Generation: 430. 正答率(トレーニング) = 0.96
#                 : 430. 正答率(テスト) = 0.8987
# Generation: 440. 正答率(トレーニング) = 0.93
#                 : 440. 正答率(テスト) = 0.8951
# Generation: 450. 正答率(トレーニング) = 0.95
#                 : 450. 正答率(テスト) = 0.889
# Generation: 460. 正答率(トレーニング) = 0.98
#                 : 460. 正答率(テスト) = 0.9002
# Generation: 470. 正答率(トレーニング) = 0.94
#                 : 470. 正答率(テスト) = 0.9018
# Generation: 480. 正答率(トレーニング) = 0.89
#                 : 480. 正答率(テスト) = 0.9005
# Generation: 490. 正答率(トレーニング) = 0.97
#                 : 490. 正答率(テスト) = 0.9088
# Generation: 500. 正答率(トレーニング) = 0.96
#                 : 500. 正答率(テスト) = 0.9053
# Generation: 510. 正答率(トレーニング) = 0.99
#                 : 510. 正答率(テスト) = 0.904
# Generation: 520. 正答率(トレーニング) = 0.97
#                 : 520. 正答率(テスト) = 0.9096
# Generation: 530. 正答率(トレーニング) = 0.94
#                 : 530. 正答率(テスト) = 0.9103
# Generation: 540. 正答率(トレーニング) = 0.95
#                 : 540. 正答率(テスト) = 0.9128
# Generation: 550. 正答率(トレーニング) = 0.93
#                 : 550. 正答率(テスト) = 0.9041
# Generation: 560. 正答率(トレーニング) = 0.96
#                 : 560. 正答率(テスト) = 0.9152
# Generation: 570. 正答率(トレーニング) = 0.96
#                 : 570. 正答率(テスト) = 0.9083
# Generation: 580. 正答率(トレーニング) = 0.98
#                 : 580. 正答率(テスト) = 0.9156
# Generation: 590. 正答率(トレーニング) = 0.95
#                 : 590. 正答率(テスト) = 0.92
# Generation: 600. 正答率(トレーニング) = 0.96
#                 : 600. 正答率(テスト) = 0.9153
# Generation: 610. 正答率(トレーニング) = 0.99
#                 : 610. 正答率(テスト) = 0.9188
# Generation: 620. 正答率(トレーニング) = 0.92
#                 : 620. 正答率(テスト) = 0.91
# Generation: 630. 正答率(トレーニング) = 0.96
#                 : 630. 正答率(テスト) = 0.9222
# Generation: 640. 正答率(トレーニング) = 0.92
#                 : 640. 正答率(テスト) = 0.9195
# Generation: 650. 正答率(トレーニング) = 0.95
#                 : 650. 正答率(テスト) = 0.9182
# Generation: 660. 正答率(トレーニング) = 0.97
#                 : 660. 正答率(テスト) = 0.915
# Generation: 670. 正答率(トレーニング) = 0.98
#                 : 670. 正答率(テスト) = 0.9219
# Generation: 680. 正答率(トレーニング) = 0.96
#                 : 680. 正答率(テスト) = 0.9212
# Generation: 690. 正答率(トレーニング) = 0.96
#                 : 690. 正答率(テスト) = 0.9246
# Generation: 700. 正答率(トレーニング) = 0.94
#                 : 700. 正答率(テスト) = 0.9262
# Generation: 710. 正答率(トレーニング) = 0.97
#                 : 710. 正答率(テスト) = 0.9277
# Generation: 720. 正答率(トレーニング) = 0.98
#                 : 720. 正答率(テスト) = 0.9249
# Generation: 730. 正答率(トレーニング) = 0.95
#                 : 730. 正答率(テスト) = 0.9261
# Generation: 740. 正答率(トレーニング) = 0.95
#                 : 740. 正答率(テスト) = 0.9256
# Generation: 750. 正答率(トレーニング) = 0.94
#                 : 750. 正答率(テスト) = 0.9287
# Generation: 760. 正答率(トレーニング) = 0.97
#                 : 760. 正答率(テスト) = 0.9282
# Generation: 770. 正答率(トレーニング) = 0.98
#                 : 770. 正答率(テスト) = 0.9293
# Generation: 780. 正答率(トレーニング) = 0.97
#                 : 780. 正答率(テスト) = 0.9293
# Generation: 790. 正答率(トレーニング) = 0.98
#                 : 790. 正答率(テスト) = 0.931
# Generation: 800. 正答率(トレーニング) = 0.99
#                 : 800. 正答率(テスト) = 0.9346
# Generation: 810. 正答率(トレーニング) = 0.97
#                 : 810. 正答率(テスト) = 0.9208
# Generation: 820. 正答率(トレーニング) = 0.98
#                 : 820. 正答率(テスト) = 0.9312
# Generation: 830. 正答率(トレーニング) = 0.98
#                 : 830. 正答率(テスト) = 0.9343
# Generation: 840. 正答率(トレーニング) = 0.96
#                 : 840. 正答率(テスト) = 0.935
# Generation: 850. 正答率(トレーニング) = 0.98
#                 : 850. 正答率(テスト) = 0.9355
# Generation: 860. 正答率(トレーニング) = 0.96
#                 : 860. 正答率(テスト) = 0.9347
# Generation: 870. 正答率(トレーニング) = 0.97
#                 : 870. 正答率(テスト) = 0.9354
# Generation: 880. 正答率(トレーニング) = 0.98
#                 : 880. 正答率(テスト) = 0.9346
# Generation: 890. 正答率(トレーニング) = 0.98
#                 : 890. 正答率(テスト) = 0.9344
# Generation: 900. 正答率(トレーニング) = 0.99
#                 : 900. 正答率(テスト) = 0.9377
# Generation: 910. 正答率(トレーニング) = 0.97
#                 : 910. 正答率(テスト) = 0.9345
# Generation: 920. 正答率(トレーニング) = 0.96
#                 : 920. 正答率(テスト) = 0.9361
# Generation: 930. 正答率(トレーニング) = 0.97
#                 : 930. 正答率(テスト) = 0.9389
# Generation: 940. 正答率(トレーニング) = 0.99
#                 : 940. 正答率(テスト) = 0.941
# Generation: 950. 正答率(トレーニング) = 0.98
#                 : 950. 正答率(テスト) = 0.9389
# Generation: 960. 正答率(トレーニング) = 0.98
#                 : 960. 正答率(テスト) = 0.9363
# Generation: 970. 正答率(トレーニング) = 0.97
#                 : 970. 正答率(テスト) = 0.9377
# Generation: 980. 正答率(トレーニング) = 0.98
#                 : 980. 正答率(テスト) = 0.9383
# Generation: 990. 正答率(トレーニング) = 0.99
#                 : 990. 正答率(テスト) = 0.9398
# Generation: 1000. 正答率(トレーニング) = 0.99
#                 : 1000. 正答率(テスト) = 0.9324

# %% [markdown]
# →バッチ正規化なしでも学習が進んだ

# %% [markdown]
# ## Adam

# %%
# データの読み込み
(x_train, d_train), (x_test, d_test) = load_mnist(normalize=True, one_hot_label=True)

print("データ読み込み完了")

# batch_normalizationの設定 ================================
# use_batchnorm = True
use_batchnorm = False
# ====================================================

network = MultiLayerNet(input_size=784, hidden_size_list=[40, 20], output_size=10, activation='sigmoid', weight_init_std=0.01,
                       use_batchnorm=use_batchnorm)

iters_num = 1000
train_size = x_train.shape[0]
batch_size = 100
learning_rate = 0.01
beta1 = 0.9
beta2 = 0.999

train_loss_list = []
accuracies_train = []
accuracies_test = []

plot_interval=10

for i in range(iters_num):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    d_batch = d_train[batch_mask]

    # 勾配
    grad = network.gradient(x_batch, d_batch)
    if i == 0:
        m = {}
        v = {}
    learning_rate_t  = learning_rate * np.sqrt(1.0 - beta2 ** (i + 1)) / (1.0 - beta1 ** (i + 1))    
    for key in ('W1', 'W2', 'W3', 'b1', 'b2', 'b3'):
        if i == 0:
            m[key] = np.zeros_like(network.params[key])
            v[key] = np.zeros_like(network.params[key])
            
        m[key] += (1 - beta1) * (grad[key] - m[key])
        v[key] += (1 - beta2) * (grad[key] ** 2 - v[key])            
        network.params[key] -= learning_rate_t * m[key] / (np.sqrt(v[key]) + 1e-7)                
        
        
    if (i + 1) % plot_interval == 0:
        accr_test = network.accuracy(x_test, d_test)
        accuracies_test.append(accr_test)        
        accr_train = network.accuracy(x_batch, d_batch)
        accuracies_train.append(accr_train)
        loss = network.loss(x_batch, d_batch)
        train_loss_list.append(loss)        
        
        print('Generation: ' + str(i+1) + '. 正答率(トレーニング) = ' + str(accr_train))
        print('                : ' + str(i+1) + '. 正答率(テスト) = ' + str(accr_test))
                

lists = range(0, iters_num, plot_interval)
plt.plot(lists, accuracies_train, label="training set")
plt.plot(lists, accuracies_test,  label="test set")
plt.legend(loc="lower right")
plt.title("accuracy")
plt.xlabel("count")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
# グラフの表示
plt.show()
# Out:
# データ読み込み完了
# Generation: 10. 正答率(トレーニング) = 0.11
#                 : 10. 正答率(テスト) = 0.1009
# Generation: 20. 正答率(トレーニング) = 0.15
#                 : 20. 正答率(テスト) = 0.1327
# Generation: 30. 正答率(トレーニング) = 0.18
#                 : 30. 正答率(テスト) = 0.2125
# Generation: 40. 正答率(トレーニング) = 0.23
#                 : 40. 正答率(テスト) = 0.2133
# Generation: 50. 正答率(トレーニング) = 0.2
#                 : 50. 正答率(テスト) = 0.2312
# Generation: 60. 正答率(トレーニング) = 0.25
#                 : 60. 正答率(テスト) = 0.2712
# Generation: 70. 正答率(トレーニング) = 0.24
#                 : 70. 正答率(テスト) = 0.286
# Generation: 80. 正答率(トレーニング) = 0.31
#                 : 80. 正答率(テスト) = 0.339
# Generation: 90. 正答率(トレーニング) = 0.32
#                 : 90. 正答率(テスト) = 0.3269
# Generation: 100. 正答率(トレーニング) = 0.38
#                 : 100. 正答率(テスト) = 0.3341
# Generation: 110. 正答率(トレーニング) = 0.5
#                 : 110. 正答率(テスト) = 0.4274
# Generation: 120. 正答率(トレーニング) = 0.55
#                 : 120. 正答率(テスト) = 0.5111
# Generation: 130. 正答率(トレーニング) = 0.5
#                 : 130. 正答率(テスト) = 0.5206
# Generation: 140. 正答率(トレーニング) = 0.58
#                 : 140. 正答率(テスト) = 0.5609
# Generation: 150. 正答率(トレーニング) = 0.49
#                 : 150. 正答率(テスト) = 0.5632
# Generation: 160. 正答率(トレーニング) = 0.6
#                 : 160. 正答率(テスト) = 0.6244
# Generation: 170. 正答率(トレーニング) = 0.58
#                 : 170. 正答率(テスト) = 0.6053
# Generation: 180. 正答率(トレーニング) = 0.66
#                 : 180. 正答率(テスト) = 0.6338
# Generation: 190. 正答率(トレーニング) = 0.68
#                 : 190. 正答率(テスト) = 0.6794
# Generation: 200. 正答率(トレーニング) = 0.8
#                 : 200. 正答率(テスト) = 0.7664
# Generation: 210. 正答率(トレーニング) = 0.87
#                 : 210. 正答率(テスト) = 0.7983
# Generation: 220. 正答率(トレーニング) = 0.83
#                 : 220. 正答率(テスト) = 0.7988
# Generation: 230. 正答率(トレーニング) = 0.85
#                 : 230. 正答率(テスト) = 0.8329
# Generation: 240. 正答率(トレーニング) = 0.85
#                 : 240. 正答率(テスト) = 0.8222
# Generation: 250. 正答率(トレーニング) = 0.84
#                 : 250. 正答率(テスト) = 0.8723
# Generation: 260. 正答率(トレーニング) = 0.91
#                 : 260. 正答率(テスト) = 0.878
# Generation: 270. 正答率(トレーニング) = 0.89
#                 : 270. 正答率(テスト) = 0.8823
# Generation: 280. 正答率(トレーニング) = 0.89
#                 : 280. 正答率(テスト) = 0.8848
# Generation: 290. 正答率(トレーニング) = 0.9
#                 : 290. 正答率(テスト) = 0.8875
# Generation: 300. 正答率(トレーニング) = 0.87
#                 : 300. 正答率(テスト) = 0.894
# Generation: 310. 正答率(トレーニング) = 0.89
#                 : 310. 正答率(テスト) = 0.9003
# Generation: 320. 正答率(トレーニング) = 0.89
#                 : 320. 正答率(テスト) = 0.8998
# Generation: 330. 正答率(トレーニング) = 0.92
#                 : 330. 正答率(テスト) = 0.9001
# Generation: 340. 正答率(トレーニング) = 0.88
#                 : 340. 正答率(テスト) = 0.9109
# Generation: 350. 正答率(トレーニング) = 0.92
#                 : 350. 正答率(テスト) = 0.9095
# Generation: 360. 正答率(トレーニング) = 0.91
#                 : 360. 正答率(テスト) = 0.9141
# Generation: 370. 正答率(トレーニング) = 0.96
#                 : 370. 正答率(テスト) = 0.9175
# Generation: 380. 正答率(トレーニング) = 0.94
#                 : 380. 正答率(テスト) = 0.9212
# Generation: 390. 正答率(トレーニング) = 0.95
#                 : 390. 正答率(テスト) = 0.918
# Generation: 400. 正答率(トレーニング) = 0.95
#                 : 400. 正答率(テスト) = 0.919
# Generation: 410. 正答率(トレーニング) = 0.91
#                 : 410. 正答率(テスト) = 0.9177
# Generation: 420. 正答率(トレーニング) = 0.95
#                 : 420. 正答率(テスト) = 0.9175
# Generation: 430. 正答率(トレーニング) = 0.97
#                 : 430. 正答率(テスト) = 0.9207
# Generation: 440. 正答率(トレーニング) = 0.93
#                 : 440. 正答率(テスト) = 0.9233
# Generation: 450. 正答率(トレーニング) = 0.94
#                 : 450. 正答率(テスト) = 0.9252
# Generation: 460. 正答率(トレーニング) = 0.93
#                 : 460. 正答率(テスト) = 0.924
# Generation: 470. 正答率(トレーニング) = 0.93
#                 : 470. 正答率(テスト) = 0.924
# Generation: 480. 正答率(トレーニング) = 0.91
#                 : 480. 正答率(テスト) = 0.9309
# Generation: 490. 正答率(トレーニング) = 0.92
#                 : 490. 正答率(テスト) = 0.9266
# Generation: 500. 正答率(トレーニング) = 0.92
#                 : 500. 正答率(テスト) = 0.9298
# Generation: 510. 正答率(トレーニング) = 0.9
#                 : 510. 正答率(テスト) = 0.9305
# Generation: 520. 正答率(トレーニング) = 0.94
#                 : 520. 正答率(テスト) = 0.9294
# Generation: 530. 正答率(トレーニング) = 0.96
#                 : 530. 正答率(テスト) = 0.9285
# Generation: 540. 正答率(トレーニング) = 0.94
#                 : 540. 正答率(テスト) = 0.9333
# Generation: 550. 正答率(トレーニング) = 0.97
#                 : 550. 正答率(テスト) = 0.933
# Generation: 560. 正答率(トレーニング) = 0.99
#                 : 560. 正答率(テスト) = 0.9363
# Generation: 570. 正答率(トレーニング) = 0.97
#                 : 570. 正答率(テスト) = 0.9367
# Generation: 580. 正答率(トレーニング) = 0.95
#                 : 580. 正答率(テスト) = 0.9356
# Generation: 590. 正答率(トレーニング) = 0.98
#                 : 590. 正答率(テスト) = 0.9339
# Generation: 600. 正答率(トレーニング) = 0.95
#                 : 600. 正答率(テスト) = 0.9353
# Generation: 610. 正答率(トレーニング) = 0.96
#                 : 610. 正答率(テスト) = 0.9356
# Generation: 620. 正答率(トレーニング) = 0.92
#                 : 620. 正答率(テスト) = 0.9376
# Generation: 630. 正答率(トレーニング) = 0.93
#                 : 630. 正答率(テスト) = 0.939
# Generation: 640. 正答率(トレーニング) = 0.96
#                 : 640. 正答率(テスト) = 0.939
# Generation: 650. 正答率(トレーニング) = 0.95
#                 : 650. 正答率(テスト) = 0.9319
# Generation: 660. 正答率(トレーニング) = 0.96
#                 : 660. 正答率(テスト) = 0.9422
# Generation: 670. 正答率(トレーニング) = 0.94
#                 : 670. 正答率(テスト) = 0.9392
# Generation: 680. 正答率(トレーニング) = 0.96
#                 : 680. 正答率(テスト) = 0.9379
# Generation: 690. 正答率(トレーニング) = 0.96
#                 : 690. 正答率(テスト) = 0.9359
# Generation: 700. 正答率(トレーニング) = 0.99
#                 : 700. 正答率(テスト) = 0.9415
# Generation: 710. 正答率(トレーニング) = 0.97
#                 : 710. 正答率(テスト) = 0.9432
# Generation: 720. 正答率(トレーニング) = 0.95
#                 : 720. 正答率(テスト) = 0.9395
# Generation: 730. 正答率(トレーニング) = 0.92
#                 : 730. 正答率(テスト) = 0.94
# Generation: 740. 正答率(トレーニング) = 0.97
#                 : 740. 正答率(テスト) = 0.9398
# Generation: 750. 正答率(トレーニング) = 0.92
#                 : 750. 正答率(テスト) = 0.9394
# Generation: 760. 正答率(トレーニング) = 0.96
#                 : 760. 正答率(テスト) = 0.9381
# Generation: 770. 正答率(トレーニング) = 0.95
#                 : 770. 正答率(テスト) = 0.9427
# Generation: 780. 正答率(トレーニング) = 0.97
#                 : 780. 正答率(テスト) = 0.9414
# Generation: 790. 正答率(トレーニング) = 0.98
#                 : 790. 正答率(テスト) = 0.9408
# Generation: 800. 正答率(トレーニング) = 0.94
#                 : 800. 正答率(テスト) = 0.9389
# Generation: 810. 正答率(トレーニング) = 0.95
#                 : 810. 正答率(テスト) = 0.9377
# Generation: 820. 正答率(トレーニング) = 0.91
#                 : 820. 正答率(テスト) = 0.9417
# Generation: 830. 正答率(トレーニング) = 0.96
#                 : 830. 正答率(テスト) = 0.9429
# Generation: 840. 正答率(トレーニング) = 0.97
#                 : 840. 正答率(テスト) = 0.9445
# Generation: 850. 正答率(トレーニング) = 0.96
#                 : 850. 正答率(テスト) = 0.9406
# Generation: 860. 正答率(トレーニング) = 0.97
#                 : 860. 正答率(テスト) = 0.9422
# Generation: 870. 正答率(トレーニング) = 0.95
#                 : 870. 正答率(テスト) = 0.9427
# Generation: 880. 正答率(トレーニング) = 0.94
#                 : 880. 正答率(テスト) = 0.9489
# Generation: 890. 正答率(トレーニング) = 0.98
#                 : 890. 正答率(テスト) = 0.9454
# Generation: 900. 正答率(トレーニング) = 0.95
#                 : 900. 正答率(テスト) = 0.944
# Generation: 910. 正答率(トレーニング) = 0.96
#                 : 910. 正答率(テスト) = 0.9457
# Generation: 920. 正答率(トレーニング) = 0.95
#                 : 920. 正答率(テスト) = 0.9487
# Generation: 930. 正答率(トレーニング) = 0.98
#                 : 930. 正答率(テスト) = 0.9473
# Generation: 940. 正答率(トレーニング) = 0.96
#                 : 940. 正答率(テスト) = 0.9459
# Generation: 950. 正答率(トレーニング) = 0.99
#                 : 950. 正答率(テスト) = 0.9451
# Generation: 960. 正答率(トレーニング) = 0.92
#                 : 960. 正答率(テスト) = 0.9446
# Generation: 970. 正答率(トレーニング) = 0.97
#                 : 970. 正答率(テスト) = 0.9469
# Generation: 980. 正答率(トレーニング) = 0.95
#                 : 980. 正答率(テスト) = 0.9473
# Generation: 990. 正答率(トレーニング) = 0.93
#                 : 990. 正答率(テスト) = 0.9491
# Generation: 1000. 正答率(トレーニング) = 0.98
#                 : 1000. 正答率(テスト) = 0.9453

# %% [markdown]
# →バッチ正規化なしでも学習が進んだ。正答率（テスト）がRSMpropよりわずかに高くなった。

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ## [try] 学習率を変えてみよう

# %% [markdown]
# ## [try] 活性化関数と重みの初期化方法を変えてみよう
# 初期状態ではsigmoid - gauss<br>
# activationはReLU、weight_init_stdは別の数値や'Xavier'・'He'に変更可能

# %% [markdown]
# ## [try] バッチ正規化をしてみよう
# use_batchnormをTrueにしよう
# Adamでバッチ正規化したケース
#
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
# データの読み込み
(x_train, d_train), (x_test, d_test) = load_mnist(normalize=True, one_hot_label=True)

print("データ読み込み完了")

# batch_normalizationの設定 ================================
use_batchnorm = True
# use_batchnorm = False
# ====================================================

network = MultiLayerNet(input_size=784, hidden_size_list=[40, 20], output_size=10, activation='sigmoid', weight_init_std=0.01,
                       use_batchnorm=use_batchnorm)

iters_num = 1000
train_size = x_train.shape[0]
batch_size = 100
learning_rate = 0.01
beta1 = 0.9
beta2 = 0.999

train_loss_list = []
accuracies_train = []
accuracies_test = []

plot_interval=10

for i in range(iters_num):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    d_batch = d_train[batch_mask]

    # 勾配
    grad = network.gradient(x_batch, d_batch)
    if i == 0:
        m = {}
        v = {}
    learning_rate_t  = learning_rate * np.sqrt(1.0 - beta2 ** (i + 1)) / (1.0 - beta1 ** (i + 1))    
    for key in ('W1', 'W2', 'W3', 'b1', 'b2', 'b3'):
        if i == 0:
            m[key] = np.zeros_like(network.params[key])
            v[key] = np.zeros_like(network.params[key])
            
        m[key] += (1 - beta1) * (grad[key] - m[key])
        v[key] += (1 - beta2) * (grad[key] ** 2 - v[key])            
        network.params[key] -= learning_rate_t * m[key] / (np.sqrt(v[key]) + 1e-7)                
        
        
    if (i + 1) % plot_interval == 0:
        accr_test = network.accuracy(x_test, d_test)
        accuracies_test.append(accr_test)        
        accr_train = network.accuracy(x_batch, d_batch)
        accuracies_train.append(accr_train)
        loss = network.loss(x_batch, d_batch)
        train_loss_list.append(loss)        
        
        print('Generation: ' + str(i+1) + '. 正答率(トレーニング) = ' + str(accr_train))
        print('                : ' + str(i+1) + '. 正答率(テスト) = ' + str(accr_test))
                

lists = range(0, iters_num, plot_interval)
plt.plot(lists, accuracies_train, label="training set")
plt.plot(lists, accuracies_test,  label="test set")
plt.legend(loc="lower right")
plt.title("accuracy")
plt.xlabel("count")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
# グラフの表示
plt.show()
# Out:
# データ読み込み完了
# Generation: 10. 正答率(トレーニング) = 0.24
#                 : 10. 正答率(テスト) = 0.2935
# Generation: 20. 正答率(トレーニング) = 0.46
#                 : 20. 正答率(テスト) = 0.3961
# Generation: 30. 正答率(トレーニング) = 0.55
#                 : 30. 正答率(テスト) = 0.5628
# Generation: 40. 正答率(トレーニング) = 0.64
#                 : 40. 正答率(テスト) = 0.674
# Generation: 50. 正答率(トレーニング) = 0.74
#                 : 50. 正答率(テスト) = 0.7114
# Generation: 60. 正答率(トレーニング) = 0.7
#                 : 60. 正答率(テスト) = 0.7418
# Generation: 70. 正答率(トレーニング) = 0.68
#                 : 70. 正答率(テスト) = 0.7626
# Generation: 80. 正答率(トレーニング) = 0.74
#                 : 80. 正答率(テスト) = 0.7872
# Generation: 90. 正答率(トレーニング) = 0.83
#                 : 90. 正答率(テスト) = 0.8131
# Generation: 100. 正答率(トレーニング) = 0.83
#                 : 100. 正答率(テスト) = 0.8377
# Generation: 110. 正答率(トレーニング) = 0.83
#                 : 110. 正答率(テスト) = 0.8422
# Generation: 120. 正答率(トレーニング) = 0.87
#                 : 120. 正答率(テスト) = 0.8399
# Generation: 130. 正答率(トレーニング) = 0.86
#                 : 130. 正答率(テスト) = 0.8605
# Generation: 140. 正答率(トレーニング) = 0.78
#                 : 140. 正答率(テスト) = 0.8492
# Generation: 150. 正答率(トレーニング) = 0.91
#                 : 150. 正答率(テスト) = 0.8725
# Generation: 160. 正答率(トレーニング) = 0.94
#                 : 160. 正答率(テスト) = 0.8766
# Generation: 170. 正答率(トレーニング) = 0.83
#                 : 170. 正答率(テスト) = 0.8749
# Generation: 180. 正答率(トレーニング) = 0.92
#                 : 180. 正答率(テスト) = 0.8763
# Generation: 190. 正答率(トレーニング) = 0.86
#                 : 190. 正答率(テスト) = 0.8784
# Generation: 200. 正答率(トレーニング) = 0.91
#                 : 200. 正答率(テスト) = 0.881
# Generation: 210. 正答率(トレーニング) = 0.91
#                 : 210. 正答率(テスト) = 0.8777
# Generation: 220. 正答率(トレーニング) = 0.87
#                 : 220. 正答率(テスト) = 0.8606
# Generation: 230. 正答率(トレーニング) = 0.95
#                 : 230. 正答率(テスト) = 0.8905
# Generation: 240. 正答率(トレーニング) = 0.9
#                 : 240. 正答率(テスト) = 0.887
# Generation: 250. 正答率(トレーニング) = 0.86
#                 : 250. 正答率(テスト) = 0.8877
# Generation: 260. 正答率(トレーニング) = 0.89
#                 : 260. 正答率(テスト) = 0.8946
# Generation: 270. 正答率(トレーニング) = 0.93
#                 : 270. 正答率(テスト) = 0.8892
# Generation: 280. 正答率(トレーニング) = 0.83
#                 : 280. 正答率(テスト) = 0.8855
# Generation: 290. 正答率(トレーニング) = 0.91
#                 : 290. 正答率(テスト) = 0.8881
# Generation: 300. 正答率(トレーニング) = 0.89
#                 : 300. 正答率(テスト) = 0.8992
# Generation: 310. 正答率(トレーニング) = 0.94
#                 : 310. 正答率(テスト) = 0.8961
# Generation: 320. 正答率(トレーニング) = 0.89
#                 : 320. 正答率(テスト) = 0.899
# Generation: 330. 正答率(トレーニング) = 0.89
#                 : 330. 正答率(テスト) = 0.9025
# Generation: 340. 正答率(トレーニング) = 0.92
#                 : 340. 正答率(テスト) = 0.9
# Generation: 350. 正答率(トレーニング) = 0.91
#                 : 350. 正答率(テスト) = 0.8992
# Generation: 360. 正答率(トレーニング) = 0.91
#                 : 360. 正答率(テスト) = 0.8982
# Generation: 370. 正答率(トレーニング) = 0.89
#                 : 370. 正答率(テスト) = 0.8991
# Generation: 380. 正答率(トレーニング) = 0.88
#                 : 380. 正答率(テスト) = 0.9013
# Generation: 390. 正答率(トレーニング) = 0.9
#                 : 390. 正答率(テスト) = 0.8972
# Generation: 400. 正答率(トレーニング) = 0.93
#                 : 400. 正答率(テスト) = 0.9072
# Generation: 410. 正答率(トレーニング) = 0.92
#                 : 410. 正答率(テスト) = 0.8999
# Generation: 420. 正答率(トレーニング) = 0.87
#                 : 420. 正答率(テスト) = 0.9004
# Generation: 430. 正答率(トレーニング) = 0.89
#                 : 430. 正答率(テスト) = 0.9056
# Generation: 440. 正答率(トレーニング) = 0.95
#                 : 440. 正答率(テスト) = 0.8926
# Generation: 450. 正答率(トレーニング) = 0.92
#                 : 450. 正答率(テスト) = 0.9063
# Generation: 460. 正答率(トレーニング) = 0.91
#                 : 460. 正答率(テスト) = 0.909
# Generation: 470. 正答率(トレーニング) = 0.91
#                 : 470. 正答率(テスト) = 0.9033
# Generation: 480. 正答率(トレーニング) = 0.92
#                 : 480. 正答率(テスト) = 0.906
# Generation: 490. 正答率(トレーニング) = 0.86
#                 : 490. 正答率(テスト) = 0.8962
# Generation: 500. 正答率(トレーニング) = 0.9
#                 : 500. 正答率(テスト) = 0.9083
# Generation: 510. 正答率(トレーニング) = 0.91
#                 : 510. 正答率(テスト) = 0.9067
# Generation: 520. 正答率(トレーニング) = 0.94
#                 : 520. 正答率(テスト) = 0.9038
# Generation: 530. 正答率(トレーニング) = 0.9
#                 : 530. 正答率(テスト) = 0.9014
# Generation: 540. 正答率(トレーニング) = 0.92
#                 : 540. 正答率(テスト) = 0.9063
# Generation: 550. 正答率(トレーニング) = 0.95
#                 : 550. 正答率(テスト) = 0.9055
# Generation: 560. 正答率(トレーニング) = 0.9
#                 : 560. 正答率(テスト) = 0.9086
# Generation: 570. 正答率(トレーニング) = 0.89
#                 : 570. 正答率(テスト) = 0.9126
# Generation: 580. 正答率(トレーニング) = 0.92
#                 : 580. 正答率(テスト) = 0.9042
# Generation: 590. 正答率(トレーニング) = 0.94
#                 : 590. 正答率(テスト) = 0.9125
# Generation: 600. 正答率(トレーニング) = 0.92
#                 : 600. 正答率(テスト) = 0.9129
# Generation: 610. 正答率(トレーニング) = 0.84
#                 : 610. 正答率(テスト) = 0.9091
# Generation: 620. 正答率(トレーニング) = 0.95
#                 : 620. 正答率(テスト) = 0.9136
# Generation: 630. 正答率(トレーニング) = 0.92
#                 : 630. 正答率(テスト) = 0.907
# Generation: 640. 正答率(トレーニング) = 0.92
#                 : 640. 正答率(テスト) = 0.8967
# Generation: 650. 正答率(トレーニング) = 0.88
#                 : 650. 正答率(テスト) = 0.9062
# Generation: 660. 正答率(トレーニング) = 0.93
#                 : 660. 正答率(テスト) = 0.9074
# Generation: 670. 正答率(トレーニング) = 0.89
#                 : 670. 正答率(テスト) = 0.9015
# Generation: 680. 正答率(トレーニング) = 0.9
#                 : 680. 正答率(テスト) = 0.909
# Generation: 690. 正答率(トレーニング) = 0.93
#                 : 690. 正答率(テスト) = 0.908
# Generation: 700. 正答率(トレーニング) = 0.91
#                 : 700. 正答率(テスト) = 0.9141
# Generation: 710. 正答率(トレーニング) = 0.93
#                 : 710. 正答率(テスト) = 0.9178
# Generation: 720. 正答率(トレーニング) = 0.92
#                 : 720. 正答率(テスト) = 0.9153
# Generation: 730. 正答率(トレーニング) = 0.92
#                 : 730. 正答率(テスト) = 0.915
# Generation: 740. 正答率(トレーニング) = 0.88
#                 : 740. 正答率(テスト) = 0.9158
# Generation: 750. 正答率(トレーニング) = 0.88
#                 : 750. 正答率(テスト) = 0.9171
# Generation: 760. 正答率(トレーニング) = 0.91
#                 : 760. 正答率(テスト) = 0.9134
# Generation: 770. 正答率(トレーニング) = 0.91
#                 : 770. 正答率(テスト) = 0.9084
# Generation: 780. 正答率(トレーニング) = 0.91
#                 : 780. 正答率(テスト) = 0.9156
# Generation: 790. 正答率(トレーニング) = 0.95
#                 : 790. 正答率(テスト) = 0.9132
# Generation: 800. 正答率(トレーニング) = 0.95
#                 : 800. 正答率(テスト) = 0.9176
# Generation: 810. 正答率(トレーニング) = 0.93
#                 : 810. 正答率(テスト) = 0.9158
# Generation: 820. 正答率(トレーニング) = 0.94
#                 : 820. 正答率(テスト) = 0.9179
# Generation: 830. 正答率(トレーニング) = 0.93
#                 : 830. 正答率(テスト) = 0.9127
# Generation: 840. 正答率(トレーニング) = 0.95
#                 : 840. 正答率(テスト) = 0.9201
# Generation: 850. 正答率(トレーニング) = 0.98
#                 : 850. 正答率(テスト) = 0.9124
# Generation: 860. 正答率(トレーニング) = 0.89
#                 : 860. 正答率(テスト) = 0.9162
# Generation: 870. 正答率(トレーニング) = 0.95
#                 : 870. 正答率(テスト) = 0.92
# Generation: 880. 正答率(トレーニング) = 0.89
#                 : 880. 正答率(テスト) = 0.9211
# Generation: 890. 正答率(トレーニング) = 0.93
#                 : 890. 正答率(テスト) = 0.9197
# Generation: 900. 正答率(トレーニング) = 0.89
#                 : 900. 正答率(テスト) = 0.9198
# Generation: 910. 正答率(トレーニング) = 0.96
#                 : 910. 正答率(テスト) = 0.9144
# Generation: 920. 正答率(トレーニング) = 0.94
#                 : 920. 正答率(テスト) = 0.9119
# Generation: 930. 正答率(トレーニング) = 0.91
#                 : 930. 正答率(テスト) = 0.9169
# Generation: 940. 正答率(トレーニング) = 0.94
#                 : 940. 正答率(テスト) = 0.9202
# Generation: 950. 正答率(トレーニング) = 0.94
#                 : 950. 正答率(テスト) = 0.9199
# Generation: 960. 正答率(トレーニング) = 0.94
#                 : 960. 正答率(テスト) = 0.917
# Generation: 970. 正答率(トレーニング) = 0.94
#                 : 970. 正答率(テスト) = 0.9204
# Generation: 980. 正答率(トレーニング) = 0.93
#                 : 980. 正答率(テスト) = 0.9167
# Generation: 990. 正答率(トレーニング) = 0.88
#                 : 990. 正答率(テスト) = 0.9187
# Generation: 1000. 正答率(トレーニング) = 0.99
#                 : 1000. 正答率(テスト) = 0.9175
